# %%
import pandas as pd
import numpy as np
import yfinance
from mpl_finance import candlestick_ohlc
import matplotlib.dates as mpl_dates
import matplotlib.pyplot as plt

from module import getTickerHistory, addFixedInvestment, test
from login import login
rs = login()

def getIpo(date):
    df = pd.read_csv('ipo_robin_5min_valid.csv', index_col=0)  
    df= df[df['Date'] < date]
    dates= df['Date'].to_list()
    tickers= df['IPO'].to_list()
    return df, dates, tickers
df_tickers, dates, tickers = getIpo('Nov 4 2021')
df_tickers.head(-5)

#need del REVE CHWA
# Out:
# /Users/h/Documents/work-python/stock-support-resistance /my_env/lib/python3.8/site-packages/mpl_finance.py:16: DeprecationWarning:
#
# ...
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
# ...
#
#   __warnings.warn('\n\n  ================================================================='+
# login successfully
#             Date   IPO
# 0    Aug 31 2021   DDI
# 2    Aug 31 2021  REVE
# 3    Aug 27 2021   SQL
# 4    Aug 26 2021  MEOA
# 6    Aug 26 2021  CCAI
# ..           ...   ...
# 703   Jan 7 2021  AGCB
# 704   Jan 7 2021  INKA
# 705   Jan 7 2021  VCKA
# 706   Jan 6 2021  PPGH
# 707   Jan 6 2021  STPC
#
# [703 rows x 2 columns]

# %%
# name = tickers[1]
# names = ["NRDS", "NRDS"]

# for name in tickers[:10]:
#     print(name)
#     d = rs.stocks.get_stock_historicals(name, interval="5minute", span="day") # "5minute","10minute","hour","day",or "week"
#     df = pd.DataFrame(data=d)

    
#     df['open_price']= round(df['open_price'].astype(float),2)
#     df['pct_change'] = df['open_price'].pct_change()

#     df[['open_price']].plot(title=name)

# %%
def get_return_tot(df):
    threshold = -0.01
    return_tot = ""
    indexes = df.index.to_list()
    for index in indexes:
        if df.loc[index]['pct_change'] < threshold : 
            end_price = df.loc[index]['open_price']
            start_price = df.loc[0]['open_price']
            return_tot_float = 1.0*100*(end_price-start_price)/start_price
            if return_tot_float < 3: return False, return_tot
            return_tot = round(return_tot_float, 2)
            break

    return True, str(return_tot) + "%"

def validfilter(name = 'NRDS'):
    d = rs.stocks.get_stock_historicals(name, interval="5minute", span="day") # "5minute","10minute","hour","day",or "week"
    df = None
    df = pd.DataFrame(data=d)

    df['open_price']= round(df['open_price'].astype(float),2)
    df['pct_change'] = df['open_price'].pct_change()
    df = df[ df['volume'] > 0  ]
    if len(df) ==0 : 
        print("volume is zero")
        return
    
    df = df.reset_index()
    df.index = df.index * 5
    for m in range(15):
        if m%5 == 0:
            if df['pct_change'][m] < 0 : return
            
    valid, return_tot = get_return_tot(df)
    if not valid: return
    df['open_price'].plot( title= name + " " + return_tot )
    plt.show()
    
# tickers = ['NRDS']
for name in tickers[:]:
    try:
        validfilter(name)
    except:
        print(name)
        continue
# Out:
# REVE
# volume is zero
# CCAI
# WAVC
# KCGI
# APMI
# CENQ
# volume is zero
# SSBK
# volume is zero
# volume is zero
# AHPA
# CPAA
# volume is zero
# volume is zero
# ROCG
# AMCI
# XPAX
# MTAL
# APTM
# MEAC
# volume is zero
# ALPA
# CLAY
# volume is zero
# CLOE
# BSAQ
# TWCB
# APAC
# CLAQ
# volume is zero
# volume is zero
# volume is zero
# ACRO
# FICV
# GGGV
# CORS
# SHQA
# GOBI
# volume is zero
# volume is zero
# MITA
# TRON
# ZT
# volume is zero
# volume is zero
# HCNE
# volume is zero
# volume is zero
# BSGA
# volume is zero
# SMIH
# SPK
# OTEC
# volume is zero
# volume is zero
# SKYA
# MCAE
# volume is zero
# volume is zero
# volume is zero
# BRIV
# volume is zero
# volume is zero
# BSKY
# TUGC
# volume is zero
# volume is zero
# volume is zero
# volume is zero
# MBTC
# volume is zero
# LCA
# volume is zero
# volume is zero
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=KVSB&interval=5minute&span=day&bounds=regular
# KVSB
# ACTD
# ...

# %%
name = "OXAC"
d = rs.stocks.get_stock_historicals(name, interval="5minute", span="day") # "5minute","10minute","hour","day",or "week"
df = pd.DataFrame(data=d)
df['open_price']= round(df['open_price'].astype(float),2)
df['open_price'].plot()
df

# %%
def get_return_tot(df):
    return_tot = ""
    indexes = df.index.to_list()
    for index in indexes:
        if df.loc[index]['pct_change'] < -0.01 : 
            end_price = df.loc[index]['open_price']
            start_price = df.loc[0]['open_price']
            print(start_price, end_price)
            return_tot = round(100*(end_price-start_price)/start_price, 2)
            break
    return str(return_tot) + "%"

name = "FNCH"
# name = "DCRD"

d = rs.stocks.get_stock_historicals(name, interval="5minute", span="day") # "5minute","10minute","hour","day",or "week"
df = pd.DataFrame(data=d)

df['open_price']= round(df['open_price'].astype(float),2)
df['pct_change'] = df['open_price'].pct_change()
df = df[ df['volume'] > 0  ]

df = df.reset_index()
df.index = df.index * 5
return_tot = get_return_tot(df)


# return_tot = ""
# indexes = df.index.to_list()
# for index in indexes:
#     if df.loc[index]['pct_change'] < 0 : 
#         end_price = df.loc[index]['open_price']
#         start_price = df.loc[0]['open_price']
#         return_tot = str(int(start_price/(end_price-start_price))) + "%"

df['open_price'].plot( title= name + " " + return_tot )
df[20:50]
