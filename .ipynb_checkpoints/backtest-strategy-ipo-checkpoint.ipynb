# %%
import pandas as pd
import numpy as np
import yfinance
from mpl_finance import candlestick_ohlc
import matplotlib.dates as mpl_dates
import matplotlib.pyplot as plt

from module import getTickerHistory, addFixedInvestment, test
from login import login
rs = login()

def getIpo(date):
    df = pd.read_csv('ipo_robin_5min_valid.csv', index_col=0)  
    df= df[df['Date'] < date]
    dates= df['Date'].to_list()
    tickers= df['IPO'].to_list()
    return df, dates, tickers
df_tickers, dates, tickers = getIpo('Nov 4 2021')
df_tickers.head(-5)

#need del REVE CHWA
# Out:
# /Users/h/Documents/work/stock-support-resistance /my_env/lib/python3.8/site-packages/mpl_finance.py:16: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   __warnings.warn('\n\n  ================================================================='+
# login successfully
#             Date   IPO
# 0    Aug 31 2021   DDI
# 2    Aug 31 2021  REVE
# 3    Aug 27 2021   SQL
# 4    Aug 26 2021  MEOA
# 6    Aug 26 2021  CCAI
# ..           ...   ...
# 703   Jan 7 2021  AGCB
# 704   Jan 7 2021  INKA
# 705   Jan 7 2021  VCKA
# 706   Jan 6 2021  PPGH
# 707   Jan 6 2021  STPC
#
# [703 rows x 2 columns]

# %%
# name = tickers[1]
# names = ["NRDS", "NRDS"]

# for name in tickers[:10]:
#     print(name)
#     d = rs.stocks.get_stock_historicals(name, interval="5minute", span="day") # "5minute","10minute","hour","day",or "week"
#     df = pd.DataFrame(data=d)

    
#     df['open_price']= round(df['open_price'].astype(float),2)
#     df['pct_change'] = df['open_price'].pct_change()

#     df[['open_price']].plot(title=name)

# %%
def get_return_tot(df):
    threshold = -0.01
    return_tot = ""
    indexes = df.index.to_list()
    for index in indexes:
        if df.loc[index]['pct_change'] < threshold : 
            end_price = df.loc[index]['open_price']
            start_price = df.loc[0]['open_price']
            return_tot_float = 1.0*100*(end_price-start_price)/start_price
            if return_tot_float < 3: return False, return_tot
            return_tot = round(return_tot_float, 2)
            break

    return True, str(return_tot) + "%"

def validfilter(name = 'NRDS'):
    d = rs.stocks.get_stock_historicals(name, interval="5minute", span="day") # "5minute","10minute","hour","day",or "week"
    df = None
    df = pd.DataFrame(data=d)

    df['open_price']= round(df['open_price'].astype(float),2)
    df['pct_change'] = df['open_price'].pct_change()
    df = df[ df['volume'] > 0  ]
    if len(df) ==0 : 
        print("volume is zero")
        return
    
    df = df.reset_index()
    df.index = df.index * 5
    for m in range(15):
        if m%5 == 0:
            if df['pct_change'][m] < 0 : return
            
    valid, return_tot = get_return_tot(df)
    if not valid: return
    df['open_price'].plot( title= name + " " + return_tot )
    plt.show()
    
# tickers = ['NRDS']
for name in tickers[:]:
    try:
        validfilter(name)
    except:
        print(name)
        continue
# Out:
# volume is zero
# volume is zero
# OXAC
# TPBA
# CNTQ
# volume is zero
# CPAA
# ASPA
# RVAC
# volume is zero
# volume is zero
# GLEE
# XPAX
# MTAL
# SWAG
# APTM
# volume is zero
# volume is zero
# ALPA
# volume is zero
# PFTA
# volume is zero
# volume is zero
# CLOE
# volume is zero
# volume is zero
# APAC
# JATT
# ARYE
# volume is zero
# NYXH
# FICV
# GGGV
# volume is zero
# volume is zero
# THCP
# volume is zero
# FTVI
# volume is zero
# volume is zero
# TRON
# MOLN
# DILA
# volume is zero
# volume is zero
# LAAA
# volume is zero
# ISAA
# GACQ
# volume is zero
# volume is zero
# volume is zero
# volume is zero
# volume is zero
# GIW
# volume is zero
# volume is zero
# volume is zero
# OSI
# ARTA
# volume is zero
# ANEB
# DKDCA
# volume is zero
# volume is zero
# BSKY
# TUGC
# GLSPT
# volume is zero
# ACBA
# MBTC
# volume is zero
# volume is zero
# GLHA
# TBSA
# volume is zero
# NBST
# volume is zero
# RKTA
# LDHA
# BYTS
# GGMC
# GXII
# volume is zero
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=VEI&interval=5minute&span=day&bounds=regular
# VEI
# FMIV
# AMAO
# GAMC
# volume is zero
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=RTPY&interval=5minute&span=day&bounds=regular
# RTPY
# PLMI
# volume is zero
# volume is zero
# volume is zero
# FVIV
# ROSS
# volume is zero
# volume is zero
# volume is zero
# GTPB
# SCAQ
# 404 Client Error: Not Found for url: https://api.robinhood.com/quotes/historicals/?symbols=ATSP&interval=5minute&span=day&bounds=regular
# ATSP
# volume is zero
# volume is zero
# FRW
# volume is zero
# DTOC
# LHAA
# ATVC
# volume is zero
# volume is zero
# PSAG
# volume is zero
# TRCA
# volume is zero
# volume is zero
# NSTD
# volume is zero
# LOKM
# DHBC
# volume is zero
# volume is zero
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=KCAC&interval=5minute&span=day&bounds=regular
# KCAC
# volume is zero
# volume is zero
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=SCR&interval=5minute&span=day&bounds=regular
# SCR
# HIII
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=SRNG&interval=5minute&span=day&bounds=regular
# SRNG
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=CMII&interval=5minute&span=day&bounds=regular
# CMII
# FACA
# KIII
# MACA
# volume is zero
# RCLF
# volume is zero
# PGRW
# volume is zero
# volume is zero
# PICC
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=KURI&interval=5minute&span=day&bounds=regular
# KURI
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=FWAA&interval=5minute&span=day&bounds=regular
# FWAA
# COVA
# GSQD
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=CENH&interval=5minute&span=day&bounds=regular
# CENH
# ASAX
# ITQ
# volume is zero
# TMAC
# volume is zero
# volume is zero
# volume is zero
# ZWRK
# volume is zero
# BLUA
# volume is zero
# volume is zero
# volume is zero
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=CAHC&interval=5minute&span=day&bounds=regular
# CAHC
# DHHC
# volume is zero
# SSAA
# volume is zero
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=LEGO&interval=5minute&span=day&bounds=regular
# LEGO
# volume is zero
# TZPS
# volume is zero
# volume is zero
# GNAC
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=ROT&interval=5minute&span=day&bounds=regular
# ROT
# MON
# volume is zero
# volume is zero
# FINM
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=BCYP&interval=5minute&span=day&bounds=regular
# BCYP
# volume is zero
# SWET
# LJAQ
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=MCAD&interval=5minute&span=day&bounds=regular
# MCAD
# LHC
# volume is zero
# GSAQ
# EPWR
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=LWAC&interval=5minute&span=day&bounds=regular
# LWAC
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=SWBK&interval=5minute&span=day&bounds=regular
# SWBK
# BLTS
# volume is zero
# INKA
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/historicals/?symbols=STPC&interval=5minute&span=day&bounds=regular
# STPC
# volume is zero
# volume is zero
# volume is zero

# %%
name = "OXAC"
d = rs.stocks.get_stock_historicals(name, interval="5minute", span="day") # "5minute","10minute","hour","day",or "week"
df = pd.DataFrame(data=d)
df['open_price']= round(df['open_price'].astype(float),2)
df['open_price'].plot()
df
# Out:
#                begins_at  open_price close_price high_price low_price  volume  \
# 0   2021-11-04T13:30:00Z        9.90    9.900000   9.900000  9.900000       0
# 1   2021-11-04T13:35:00Z        9.90    9.900000   9.900000  9.900000       0
# 2   2021-11-04T13:40:00Z        9.90    9.900000   9.900000  9.900000       0
# 3   2021-11-04T13:45:00Z        9.90    9.900000   9.900000  9.900000       0
# 4   2021-11-04T13:50:00Z        9.90    9.900000   9.900000  9.900000       0
# ..                   ...         ...         ...        ...       ...     ...
# 73  2021-11-04T19:35:00Z        9.91    9.910000   9.910000  9.910000       0
# 74  2021-11-04T19:40:00Z        9.91    9.910000   9.910000  9.910000       0
# 75  2021-11-04T19:45:00Z        9.91    9.910000   9.910000  9.910000       0
# 76  2021-11-04T19:50:00Z        9.91    9.910000   9.910000  9.910000       0
# 77  2021-11-04T19:55:00Z        9.91    9.910000   9.910000  9.910000       0
#
#    session  interpolated symbol
# 0      reg          True   OXAC
# 1      reg          True   OXAC
# 2      reg          True   OXAC
# 3      reg          True   OXAC
# 4      reg          True   OXAC
# ..     ...           ...    ...
# 73     reg          True   OXAC
# 74     reg          True   OXAC
# 75     reg          True   OXAC
# 76     reg          True   OXAC
# 77     reg          True   OXAC
#
# [78 rows x 9 columns]

# %%
def get_return_tot(df):
    return_tot = ""
    indexes = df.index.to_list()
    for index in indexes:
        if df.loc[index]['pct_change'] < -0.01 : 
            end_price = df.loc[index]['open_price']
            start_price = df.loc[0]['open_price']
            print(start_price, end_price)
            return_tot = round(100*(end_price-start_price)/start_price, 2)
            break
    return str(return_tot) + "%"

name = "FNCH"
# name = "DCRD"

d = rs.stocks.get_stock_historicals(name, interval="5minute", span="day") # "5minute","10minute","hour","day",or "week"
df = pd.DataFrame(data=d)

df['open_price']= round(df['open_price'].astype(float),2)
df['pct_change'] = df['open_price'].pct_change()
df = df[ df['volume'] > 0  ]

df = df.reset_index()
df.index = df.index * 5
return_tot = get_return_tot(df)


# return_tot = ""
# indexes = df.index.to_list()
# for index in indexes:
#     if df.loc[index]['pct_change'] < 0 : 
#         end_price = df.loc[index]['open_price']
#         start_price = df.loc[0]['open_price']
#         return_tot = str(int(start_price/(end_price-start_price))) + "%"

df['open_price'].plot( title= name + " " + return_tot )
df[20:50]
# Out:
# 13.41 14.23
#      index             begins_at  open_price close_price high_price  \
# 100     24  2021-11-04T15:30:00Z       14.44   14.440000  14.440000
# 105     26  2021-11-04T15:40:00Z       14.44   14.440000  14.440000
# 110     28  2021-11-04T15:50:00Z       14.44   14.340000  14.480000
# 115     29  2021-11-04T15:55:00Z       14.34   14.430000  14.430000
# 120     30  2021-11-04T16:00:00Z       14.32   14.320000  14.320000
# 125     31  2021-11-04T16:05:00Z       14.11   14.110000  14.110000
# 130     32  2021-11-04T16:10:00Z       14.11   14.250000  14.250000
# 135     33  2021-11-04T16:15:00Z       14.15   14.150000  14.150000
# 140     34  2021-11-04T16:20:00Z       14.13   14.130000  14.130000
# 145     35  2021-11-04T16:25:00Z       14.05   14.160000  14.180000
# 150     36  2021-11-04T16:30:00Z       14.15   14.120000  14.190000
# 155     37  2021-11-04T16:35:00Z       14.11   14.170000  14.170000
# 160     38  2021-11-04T16:40:00Z       14.12   14.120000  14.120000
# 165     39  2021-11-04T16:45:00Z       14.15   14.145000  14.147500
# 170     41  2021-11-04T16:55:00Z       14.14   14.090000  14.140000
# 175     43  2021-11-04T17:05:00Z       14.09   14.070000  14.100000
# 180     44  2021-11-04T17:10:00Z       14.14   14.040000  14.135000
# 185     45  2021-11-04T17:15:00Z       14.04   14.040000  14.040000
# 190     46  2021-11-04T17:20:00Z       14.14   14.130000  14.220000
# 195     47  2021-11-04T17:25:00Z       14.14   14.040000  14.135000
# 200     50  2021-11-04T17:40:00Z       13.98   13.985000  13.985000
# 205     51  2021-11-04T17:45:00Z       14.19   14.195000  14.195000
# 210     52  2021-11-04T17:50:00Z       14.11   14.040000  14.110000
# 215     53  2021-11-04T17:55:00Z       14.10   14.030000  14.095000
# 220     54  2021-11-04T18:00:00Z       14.12   14.118400  14.118400
# 225     55  2021-11-04T18:05:00Z       14.03   14.030000  14.030000
# 230     56  2021-11-04T18:10:00Z       14.02   14.025000  14.025000
# 235     57  2021-11-04T18:15:00Z       14.08   14.025000  14.085000
# 240     58  2021-11-04T18:20:00Z       14.00   13.860000  14.000000
# 245     60  2021-11-04T18:30:00Z       13.92   13.915000  13.915000
#
#      low_price  volume session  interpolated symbol  pct_change
# 100  14.440000     200     reg         False   FNCH   -0.002762
# 105  14.440000     100     reg         False   FNCH    0.000000
# 110  14.340000    1250     reg         False   FNCH    0.000000
# 115  14.340000     300     reg         False   FNCH   -0.006925
# 120  14.320000     200     reg         False   FNCH   -0.001395
# 125  14.110000     200     reg         False   FNCH   -0.014665
# 130  14.110100    1000     reg         False   FNCH    0.000000
# 135  14.150000     200     reg         False   FNCH    0.002835
# 140  14.130000     200     reg         False   FNCH   -0.001413
# 145  14.050000    1100     reg         False   FNCH   -0.005662
# 150  14.120000     650     reg         False   FNCH    0.007117
# 155  14.110000     300     reg         False   FNCH   -0.002827
# 160  14.120000     100     reg         False   FNCH    0.000709
# 165  14.145000     202     reg         False   FNCH    0.002125
# 170  14.090000     507     reg         False   FNCH    0.000000
# 175  14.070000     400     reg         False   FNCH    0.000000
# 180  14.040000     400     reg         False   FNCH    0.003549
# 185  14.040000     100     reg         False   FNCH   -0.007072
# 190  14.130000     300     reg         False   FNCH    0.007123
# 195  14.040000     300     reg         False   FNCH    0.000000
# 200  13.985000     100     reg         False   FNCH   -0.004274
# 205  14.190000     200     reg         False   FNCH    0.015021
# 210  14.040000     200     reg         False   FNCH   -0.005638
# 215  14.010000     600     reg         False   FNCH   -0.000709
# 220  14.118400     600     reg         False   FNCH    0.001418
# 225  14.030000     400     reg         False   FNCH   -0.006374
# 230  14.025000     100     reg         False   FNCH   -0.000713
# 235  14.025000     300     reg         False   FNCH    0.004280
# 240  13.860000     400     reg         False   FNCH   -0.005682
# 245  13.915000     100     reg         False   FNCH    0.004329
